# %%
import pandas as pd
import numpy as np
a=pd.read_csv("ai_financial_market_daily_realistic_synthetic.csv")
a
# Out:
#              Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0      2015-01-01  OpenAI                 5.92               0.63
# 1      2015-01-02  OpenAI                 5.41               1.81
# 2      2015-01-03  OpenAI                 4.50               0.61
# 3      2015-01-04  OpenAI                 5.45               0.95
# 4      2015-01-05  OpenAI                 3.40               1.48
# ...           ...     ...                  ...                ...
# 10954  2024-12-27    Meta               100.19             103.54
# 10955  2024-12-28    Meta                99.12             102.37
# 10956  2024-12-29    Meta                98.95             103.11
# 10957  2024-12-30    Meta               100.74             103.21
# 10958  2024-12-31    Meta               100.08             103.41
#
#        AI_Revenue_Growth_% Event  Stock_Impact_%
# 0                   -36.82   NaN           -0.36
# 1                    80.59   NaN            0.41
# ...

# %%
a.info() #deatails about ds
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10959 entries, 0 to 10958
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 10959 non-null  object
#  1   Company              10959 non-null  object
#  2   R&D_Spending_USD_Mn  10959 non-null  float64
#  3   AI_Revenue_USD_Mn    10959 non-null  float64
#  4   AI_Revenue_Growth_%  10959 non-null  float64
#  5   Event                233 non-null    object
#  6   Stock_Impact_%       10959 non-null  float64
# dtypes: float64(4), object(3)
# memory usage: 599.4+ KB

# %%
a['Date']=pd.to_datetime(a['Date'])  #used to change dtype for time

# %%
a['month']=a["Date"].dt.month
a
# Out:
#             Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0     2015-01-01  OpenAI                 5.92               0.63
# 1     2015-01-02  OpenAI                 5.41               1.81
# 2     2015-01-03  OpenAI                 4.50               0.61
# 3     2015-01-04  OpenAI                 5.45               0.95
# 4     2015-01-05  OpenAI                 3.40               1.48
# ...          ...     ...                  ...                ...
# 10954 2024-12-27    Meta               100.19             103.54
# 10955 2024-12-28    Meta                99.12             102.37
# 10956 2024-12-29    Meta                98.95             103.11
# 10957 2024-12-30    Meta               100.74             103.21
# 10958 2024-12-31    Meta               100.08             103.41
#
#        AI_Revenue_Growth_% Event  Stock_Impact_%  month
# 0                   -36.82   NaN           -0.36      1
# 1                    80.59   NaN            0.41      1
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10959 entries, 0 to 10958
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 10959 non-null  datetime64[ns]
#  1   Company              10959 non-null  object
#  2   R&D_Spending_USD_Mn  10959 non-null  float64
#  3   AI_Revenue_USD_Mn    10959 non-null  float64
#  4   AI_Revenue_Growth_%  10959 non-null  float64
#  5   Event                233 non-null    object
#  6   Stock_Impact_%       10959 non-null  float64
#  7   month                10959 non-null  int32
# dtypes: datetime64[ns](1), float64(4), int32(1), object(2)
# memory usage: 642.3+ KB

# %%
a.isnull().sum()
# Out:
# Date                       0
# Company                    0
# R&D_Spending_USD_Mn        0
# AI_Revenue_USD_Mn          0
# AI_Revenue_Growth_%        0
# Event                  10726
# Stock_Impact_%             0
# month                      0
# dtype: int64

# %%
a.duplicated().sum()
# Out:
# np.int64(0)

# %%
a.groupby(["Company"]).groups #groups
# Out:
# {'Google': [3653, 3654, 3655, 3656, 3657, 3658, 3659, 3660, 3661, 3662, 3663, 3664, 3665, 3666, 3667, 3668, 3669, 3670, 3671, 3672, 3673, 3674, 3675, 3676, 3677, 3678, 3679, 3680, 3681, 3682, 3683, 3684, 3685, 3686, 3687, 3688, 3689, 3690, 3691, 3692, 3693, 3694, 3695, 3696, 3697, 3698, 3699, 3700, 3701, 3702, 3703, 3704, 3705, 3706, 3707, 3708, 3709, 3710, 3711, 3712, 3713, 3714, 3715, 3716, 3717, 3718, 3719, 3720, 3721, 3722, 3723, 3724, 3725, 3726, 3727, 3728, 3729, 3730, 3731, 3732, 3733, 3734, 3735, 3736, 3737, 3738, 3739, 3740, 3741, 3742, 3743, 3744, 3745, 3746, 3747, 3748, 3749, 3750, 3751, 3752, ...], 'Meta': [7306, 7307, 7308, 7309, 7310, 7311, 7312, 7313, 7314, 7315, 7316, 7317, 7318, 7319, 7320, 7321, 7322, 7323, 7324, 7325, 7326, 7327, 7328, 7329, 7330, 7331, 7332, 7333, 7334, 7335, 7336, 7337, 7338, 7339, 7340, 7341, 7342, 7343, 7344, 7345, 7346, 7347, 7348, 7349, 7350, 7351, 7352, 7353, 7354, 7355, 7356, 7357, 7358, 7359, 7360, 7361, 7362, 7363, 7364, 7365, 7366, 7367,
# ...

# %%
#df.groupby(col).get_group("groupname")
a.groupby("Company").get_group("Meta")
# Out:
#             Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 7306  2015-01-01    Meta                50.39              18.95
# 7307  2015-01-02    Meta                49.80              19.77
# 7308  2015-01-03    Meta                49.09              19.96
# 7309  2015-01-04    Meta                50.66              20.48
# 7310  2015-01-05    Meta                51.36              19.84
# ...          ...     ...                  ...                ...
# 10954 2024-12-27    Meta               100.19             103.54
# 10955 2024-12-28    Meta                99.12             102.37
# 10956 2024-12-29    Meta                98.95             103.11
# 10957 2024-12-30    Meta               100.74             103.21
# 10958 2024-12-31    Meta               100.08             103.41
#
#        AI_Revenue_Growth_% Event  Stock_Impact_%  month
# 7306                 -5.23   NaN           -0.42      1
# 7307                 -1.16   NaN            0.63      1
# ...

# %%
#sigle agg   df.groupby(col)[colname].agg
a.groupby(["Company"])["AI_Revenue_Growth_%"].mean()
# Out:
# Company
# Google    159.602313
# Meta      159.542223
# OpenAI    159.043427
# Name: AI_Revenue_Growth_%, dtype: float64

# %%
#multiple agg  df.groupby(col).agg({col:agg,col:agg})
a.groupby(["Company"]).agg({"AI_Revenue_USD_Mn":"sum","R&D_Spending_USD_Mn":"median"})
# Out:
#          AI_Revenue_USD_Mn  R&D_Spending_USD_Mn
# Company
# Google           284498.38               114.50
# Meta             189621.82                70.96
# OpenAI             9462.89                 7.15

# %% [markdown]
# # error=coerce - numeric
# # error=ignore  -used to ingore empty space to NaN

# %% [markdown]
# 1. What is the total AI revenue generated by each company?
#
#
# 2. What is the average R&D spending per company?
#
#
# 3. Which company has the highest average AI revenue growth (%)?
#
#
# 4. What is the total stock impact (%) for each company?
#
#
# 5. What is the average AI revenue per year across all companies?

# %%
#1
v=a.groupby("Company")["AI_Revenue_USD_Mn"].sum()
v
# Out:
# Company
# Google    284498.38
# Meta      189621.82
# OpenAI      9462.89
# Name: AI_Revenue_USD_Mn, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.pie(v.values,autopct='%1.1f%%',labels=v.index,startangle=90)
plt.show()

# %% [markdown]
# 1.google is the higest AI revenue generated
# 2.open AI is generate the lowest revenue
# 3.meta has 39.2 % of revenue generated

# %%
#2
x=a.groupby("Company")["R&D_Spending_USD_Mn"].mean()
x
# Out:
# Company
# Google    115.888623
# Meta       72.415294
# OpenAI      7.249595
# Name: R&D_Spending_USD_Mn, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.pie(x.values,autopct='%1.1f%%',colors=["red","blue","yellow"],labels=x.index,startangle=90)
plt.show()

# %% [markdown]
# 1.google is most spending on R&D spending_USD_mn
# 2.open AI is least spending on R&D spending_USD_mn
# 3.meta is second highest spending(39.2%)

# %%
#3
y=a.groupby("Company")["AI_Revenue_Growth_%"].mean()
y
# Out:
# Company
# Google    159.602313
# Meta      159.542223
# OpenAI    159.043427
# Name: AI_Revenue_Growth_%, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.pie(y.values,autopct='%1.11f%%',colors=["red","blue","yellow"],labels=y.index,startangle=90)
plt.show()

# %% [markdown]
# 1.google has the higest average of AI revenue growth
# 2.meta  has the  second higest average of AI revenue growth
# 3.open has the lowest average of AI revenue growth

# %%
#4
c=a.groupby("Company")["Stock_Impact_%"].sum()
c
# Out:
# Company
# Google     95.74
# Meta       35.66
# OpenAI    148.71
# Name: Stock_Impact_%, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.pie(c.values,autopct='%1.1f%%',colors=["red","blue","yellow"],labels=c.index,startangle=90)
plt.show()

# %% [markdown]
# 1.Open AI has the higest stock impact
# 2.meta has the lowest stock impact %
# 3.google has the second  higest stock impact %

# %%
#5
a["Year"] = a["Date"].dt.year
p=a.groupby("Year")["AI_Revenue_USD_Mn"].mean()
p
# Out:
# Year
# 2015    17.007498
# 2016    20.365392
# 2017    24.453699
# 2018    29.373918
# 2019    35.233169
# 2020    42.309827
# 2021    50.768164
# 2022    60.889717
# 2023    73.097388
# 2024    87.717587
# Name: AI_Revenue_USD_Mn, dtype: float64

# %%
plt.figure(figsize=(8,6))
plt.bar(p.index,p.values,color="blue",label="year")
plt.title("AI revenues per year")
plt.xlabel("years")
plt.ylabel("revenue")
plt.grid()
plt.show()

# %% [markdown]
# 1. 2024 has the higest AI revenue per year
# 2. 2015 has the lowest AI revenue per year
# 3.2016 has the second lowest AI revenue per year

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(3, 2, figsize=(12, 10))

axs[2,1].bar(p.index, p.values, color="blue")
axs[2,1].set_title("AI revenues per year")

axs[0,1].pie(x.values, autopct='%1.1f%%', labels=x.index, startangle=90)
axs[0,1].set_title(" ")

axs[1,0].pie(y.values, autopct='%1.1f%%', labels=y.index, startangle=90)
axs[1,0].set_title("")

axs[1,1].pie(c.values, autopct='%1.1f%%', labels=c.index, startangle=90)
axs[1,1].set_title("")

axs[0,0].pie(v.values, autopct='%1.1f%%', labels=v.index, startangle=90)
axs[0,0].set_title("revenuue per company")

plt.tight_layout()
plt.show()
